# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'geocoding_gerry.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'VoterFile1.csv',
#  'VoterFile10.csv',
#  'VoterFile100.csv',
#  'VoterFile1000.csv',
#  'VoterFile500.csv']

# %%
import pandas
df=pandas.read_csv("VoterFile10.csv")
df
# Out:
#     VOTER_ID     COUNTY FIRST_NAME MIDDLE_NAME    LAST_NAME  NAME_SUFFIX  \
# 0  600028381       Park    GILBERT      ARTHUR         ROSS          NaN
# 1    1460048     Denver    CHRISTA   ELIZABETH    TRIFANOFF          NaN
# 2     547847       Park  KATHERINE        JANE  MASTROIANNI          NaN
# 3  601171490     Denver        EVE    VICTORIA        SCOTT          NaN
# 4  200023657    El Paso     YVONNE     CUCHENS       NELSON          NaN
# 5  200273982    El Paso      KAELI        LYNN         MORA          NaN
# 6  601498361  Jefferson     CONNOR      ANDREW       MATEER          NaN
# 7  601371738       Weld    TRISTAN        ERIN        OLIVA          NaN
# 8  600390117       Mesa       DORA     VANESSA        GOMEZ          NaN
# 9    2264586       Mesa     DONALD         LEE        SMITH          NaN
#
#   REGISTRATION_DATE EFFECTIVE_DATE LAST_UPDATED_DATE   OLD_VOTER_ID  ...  \
# 0        11/29/2007      9/23/2014         9/23/2014            NaN  ...
# 1         9/10/2012      5/20/2014        11/28/2018      35-268158  ...
# 2         3/31/1994      6/23/2008        11/21/2018  47-4794000177  ...
# 3          7/5/2018      9/13/2018        11/28/2018            NaN  ...
# 4         2/19/2008      6/15/2018        12/20/2016            NaN  ...
# 5         4/14/2010      6/20/2018        11/22/2016            NaN  ...
# 6        10/23/2016      11/6/2018        11/29/2018            NaN  ...
# 7         8/16/2016      11/6/2018        11/27/2018            NaN  ...
# 8        10/19/2011      11/6/2018        11/20/2018            NaN  ...
# 9          2/3/2006       5/6/2014        11/20/2018      39-118472  ...
#
#   Water Conservancy  Water Conservancy 2  Water Conservancy 3  \
# 0             47800              47801.0                  NaN
# 1               NaN                  NaN                  NaN
# 2             47800              47801.0                  NaN
# 3               NaN                  NaN                  NaN
# 4            SOU WC                  NaN                  NaN
# 5            SOU WC                  NaN                  NaN
# 6               NaN                  NaN                  NaN
# 7             NCWCD                  NaN                  NaN
# 8               NaN                  NaN                  NaN
# 9               NaN                  NaN                  NaN
#
#   Water Conservation Water Conservation 2 Water  Water 2 Water Sub  \
# 0                NaN                  NaN   NaN      NaN       NaN
# 1                NaN                  NaN   NaN      NaN       NaN
# 2                NaN                  NaN   NaN      NaN       NaN
# 3                NaN                  NaN   NaN      NaN       NaN
# 4                NaN                  NaN   NaN      NaN       NaN
# 5                NaN                  NaN   NaN      NaN       NaN
# 6                NaN                  NaN   NaN      NaN       NaN
# 7                NaN                  NaN   NaN      NaN       NaN
# 8                NaN                  NaN   NaN      NaN       NaN
# 9                NaN                  NaN   NaN      NaN       NaN
#
#   Water Quality Authority Weed and Pest Control
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# 5                     NaN                   NaN
# 6                     NaN                   NaN
# 7                     NaN                   NaN
# 8                     NaN                 GRMCD
# 9                     NaN                 GRMCD
#
# [10 rows x 155 columns]

# %%
df.drop(df.columns[0:11], axis=1)
# Out:
#    HOUSE_NUM  HOUSE_SUFFIX PRE_DIR     STREET_NAME STREET_TYPE  POST_DIR  \
# 0         12           NaN       S            MAIN          ST       NaN
# 1       1715           NaN       E            16TH         AVE       NaN
# 2        362           NaN     NaN   DICK MOUNTAIN          DR       NaN
# 3       1200           NaN       S          ONEIDA          ST       NaN
# 4       1830           NaN     NaN        WOODBURN          ST       NaN
# 5       1830           NaN     NaN        WOODBURN          ST       NaN
# 6       5409           NaN       S            IRIS          ST       NaN
# 7      10685           NaN     NaN  COUNTY ROAD 23         NaN       NaN
# 8       2634           NaN     NaN       PATTERSON          RD       NaN
# 9       3032           NaN     NaN       BOOKCLIFF         AVE       NaN
#
#   UNIT_TYPE UNIT_NUM         RESIDENTIAL_ADDRESS RESIDENTIAL_CITY  ...  \
# 0       NaN      NaN                12 S MAIN ST             ALMA  ...
# 1       NaN      NaN             1715 E 16TH AVE           DENVER  ...
# 2       NaN      NaN        362 DICK MOUNTAIN DR           BAILEY  ...
# 3       APT    5-208  1200 S ONEIDA ST APT 5-208           DENVER  ...
# 4       NaN      NaN            1830 WOODBURN ST     COLO SPRINGS  ...
# 5       NaN      NaN            1830 WOODBURN ST     COLO SPRINGS  ...
# 6       NaN      NaN              5409 S IRIS ST        LITTLETON  ...
# 7       NaN      NaN        10685 COUNTY ROAD 23        FT LUPTON  ...
# 8       NaN      NaN           2634 PATTERSON RD   GRAND JUNCTION  ...
# 9       NaN      NaN          3032 BOOKCLIFF AVE   GRAND JUNCTION  ...
#
#   Water Conservancy  Water Conservancy 2  Water Conservancy 3  \
# 0             47800              47801.0                  NaN
# 1               NaN                  NaN                  NaN
# 2             47800              47801.0                  NaN
# 3               NaN                  NaN                  NaN
# 4            SOU WC                  NaN                  NaN
# 5            SOU WC                  NaN                  NaN
# 6               NaN                  NaN                  NaN
# 7             NCWCD                  NaN                  NaN
# 8               NaN                  NaN                  NaN
# 9               NaN                  NaN                  NaN
#
#   Water Conservation  Water Conservation 2  Water Water 2 Water Sub  \
# 0                NaN                   NaN    NaN     NaN       NaN
# 1                NaN                   NaN    NaN     NaN       NaN
# 2                NaN                   NaN    NaN     NaN       NaN
# 3                NaN                   NaN    NaN     NaN       NaN
# 4                NaN                   NaN    NaN     NaN       NaN
# 5                NaN                   NaN    NaN     NaN       NaN
# 6                NaN                   NaN    NaN     NaN       NaN
# 7                NaN                   NaN    NaN     NaN       NaN
# 8                NaN                   NaN    NaN     NaN       NaN
# 9                NaN                   NaN    NaN     NaN       NaN
#
#    Water Quality Authority  Weed and Pest Control
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# 5                      NaN                    NaN
# 6                      NaN                    NaN
# 7                      NaN                    NaN
# 8                      NaN                  GRMCD
# 9                      NaN                  GRMCD
#
# [10 rows x 144 columns]

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.75299358728148

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75644449321933, -122.42935314363206, 0.0))

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"]=df["Coordinates"].apply(lambda y: y.longitude if y != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# 0  (3666 21st St, San Francisco, California, 9411...  37.756444 -122.429353
# 1  (735 Dolores St, San Francisco, California, 94...  37.757801 -122.425594
# 2  (332 Hill St, San Francisco, California, 94114...  37.755650 -122.428790
# 3  (3995 23rd St, San Francisco, California, 9411...  37.752994 -122.431697
# 4  (1056 Sanchez St, San Francisco, California, 9...  37.752144 -122.429754
# 5  (551 Alvarado St, San Francisco, California, 9...  37.753709 -122.433246
