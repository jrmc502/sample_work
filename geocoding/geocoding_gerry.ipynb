# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'geocoding_gerry.ipynb',
#  'geocoding_gerry.py',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'VoterFile1.csv',
#  'VoterFile10.csv',
#  'VoterFile10.xlsx',
#  'VoterFile100.csv',
#  'VoterFile1000.csv',
#  'VoterFile10_clean.csv',
#  'VoterFile500.csv']

# %%
import pandas
df=pandas.read_csv("VoterFile1000.csv")
df
# Out:
#       VOTER_ID      COUNTY   FIRST_NAME MIDDLE_NAME      LAST_NAME  \
# 0    600028381        Park      GILBERT      ARTHUR           ROSS
# 1      1460048      Denver      CHRISTA   ELIZABETH      TRIFANOFF
# 2       547847        Park    KATHERINE        JANE    MASTROIANNI
# 3    601171490      Denver          EVE    VICTORIA          SCOTT
# 4    200023657     El Paso       YVONNE     CUCHENS         NELSON
# 5    200273982     El Paso        KAELI        LYNN           MORA
# 6    601498361   Jefferson       CONNOR      ANDREW         MATEER
# 7    601371738        Weld      TRISTAN        ERIN          OLIVA
# 8    600390117        Mesa         DORA     VANESSA          GOMEZ
# 9      2264586        Mesa       DONALD         LEE          SMITH
# 10   601185148        Park        JAMES       DAVID          ACKER
# 11      545464        Park         TONY         RAY         HUDSON
# 12   200200010     Larimer        TERIN     DEARING  DEVOTO NOONAN
# ...

# %%
df1= df.iloc[:,[19,20,21,22,23]]
df1
# Out:
#               RESIDENTIAL_ADDRESS RESIDENTIAL_CITY RESIDENTIAL_STATE  \
# 0                    12 S MAIN ST             ALMA                CO
# 1                 1715 E 16TH AVE           DENVER                CO
# 2            362 DICK MOUNTAIN DR           BAILEY                CO
# 3      1200 S ONEIDA ST APT 5-208           DENVER                CO
# 4                1830 WOODBURN ST     COLO SPRINGS                CO
# 5                1830 WOODBURN ST     COLO SPRINGS                CO
# 6                  5409 S IRIS ST        LITTLETON                CO
# 7            10685 COUNTY ROAD 23        FT LUPTON                CO
# 8               2634 PATTERSON RD   GRAND JUNCTION                CO
# 9              3032 BOOKCLIFF AVE   GRAND JUNCTION                CO
# 10           350 COTTAGE GROVE RD             ALMA                CO
# 11                 510 BURLAND DR           BAILEY                CO
# 12                  522 E 42ND ST         LOVELAND                CO
# ...

# %%
df1["RESIDENTIAL_ADDRESS"]=df1["RESIDENTIAL_ADDRESS"]+", "+df1["RESIDENTIAL_CITY"]+", "+df1["RESIDENTIAL_STATE"]+", "+df1["RESIDENTIAL_ZIP_CODE"].apply(str) 
df1
# Out:
# c:\users\pc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                    RESIDENTIAL_ADDRESS RESIDENTIAL_CITY  \
# 0                      12 S MAIN ST, ALMA, CO, 80420.0             ALMA
# 1                 1715 E 16TH AVE, DENVER, CO, 80218.0           DENVER
# 2            362 DICK MOUNTAIN DR, BAILEY, CO, 80421.0           BAILEY
# 3      1200 S ONEIDA ST APT 5-208, DENVER, CO, 80224.0           DENVER
# 4          1830 WOODBURN ST, COLO SPRINGS, CO, 80905.0     COLO SPRINGS
# 5          1830 WOODBURN ST, COLO SPRINGS, CO, 80905.0     COLO SPRINGS
# ...

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("12 S MAIN ST, ALMA, CO, 0 80420")

# %%
n.latitude
# Out:
# 39.2835028035085

# %%
n.longitude
# Out:
# -106.06241581277067

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import timeit

# %%
import timeit
tic=timeit.default_timer()
#main chunk
Coordinates = df1["RESIDENTIAL_ADDRESS"].apply(nom.geocode, timeout=10)
df1["Coordinates"]= Coordinates
df1
#this is the time stamp.
toc=timeit.default_timer()
# Out:
# c:\users\pc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
print (toc-tic)
# Out:
# 619.4849756750004

# %%
df.Coordinates[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-2e445ce25217> in <module>
# ----> 1 df.Coordinates[0]
#
# c:\users\pc\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Coordinates'

# %%
df1["Latitude"]=df1["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df1["Longitude"]=df1["Coordinates"].apply(lambda y: y.longitude if y != None else None)
df1
#This adds latitude and longitude to their new respective columns.
# Out:
# c:\users\pc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\pc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    RESIDENTIAL_ADDRESS RESIDENTIAL_CITY  \
# 0                      12 S MAIN ST, ALMA, CO, 80420.0             ALMA
# ...
